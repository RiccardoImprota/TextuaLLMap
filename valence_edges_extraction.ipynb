# %%
from emoatlas import EmoScores
import os
import json
import re
from pprint import pprint
from collections import defaultdict
from emoatlas.resources import _valences
import random
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats



emos=EmoScores()

# %%
base_output_dir = "localdb"
valence_dir = "Valence_Metrics"

# Folders of interest
folders_of_interest = ['climate', 'math', 'misinformation_health','gwarming']
folders_of_interest = ['misinformation_health']

# %%
def extract_model(filename):
    if filename.endswith('.jsonl'):
        return filename[:-6]  # Remove the last 6 characters
    else:
        return filename

# %%
def get_valence_sets(weighted_fmnt, language='english'):
    
    positive, negative, ambivalent = _valences(language)
    

    all_nodes = set(node for edge in weighted_fmnt for node in edge[:2])

    print('wtf:', all_nodes)



    positive_nodes = all_nodes.intersection(positive)
    print(positive_nodes)
    negative_nodes = all_nodes.intersection(negative)
    neutral_nodes = all_nodes - (positive_nodes | negative_nodes )

    return positive_nodes, negative_nodes, neutral_nodes

# %%
def swap_elements_in_sets(set1, set2, set3):
    # Calculate total number of elements
    total_elements = len(set1) + len(set2) + len(set3)
    
    # Convert sets to lists for easy manipulation
    lists = [list(set1), list(set2), list(set3)]
    
    # Perform swapping operations
    for _ in range(10 * total_elements):
        # Pick 2 random sets without repetition
        set_indices = random.sample(range(3), 2)
        
        # Pick a random word from each set
        word1 = random.choice(lists[set_indices[0]])
        word2 = random.choice(lists[set_indices[1]])
        
        # Only swap if the words don't already exist in the other list
        if word1 not in lists[set_indices[1]] and word2 not in lists[set_indices[0]]:
            lists[set_indices[0]].remove(word1)
            lists[set_indices[1]].remove(word2)
            lists[set_indices[0]].append(word2)
            lists[set_indices[1]].append(word1)
    
    # Convert lists back to sets
    return set(lists[0]), set(lists[1]), set(lists[2])

# %%
print(type(weighted_fmnt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(type(weighted_fmnt))
#
# NameError: name 'weighted_fmnt' is not defined

# %%
def export_loop_valences():
    for folder in folders_of_interest:
        input_folder_path = os.path.join(base_output_dir, folder)
        valence_output_path = os.path.join(valence_dir, folder)

        for filename in os.listdir(input_folder_path):
            print(filename.rstrip('.jsonl'))

            file_path = os.path.join(input_folder_path, filename)
            with open(file_path, 'r') as file:
                fmnts = []
                for line in file:
                    data = json.loads(line)
                    fmnts.append(data['fmnt']['syntactic'])
            
            weighted_fmnt = emos.combine_formamentis(fmnts, weights=True)
            if 'ITA' in filename:
                language = 'italian'
            else:
                language = 'english'

            positive, negative, neutral = get_valence_sets(weighted_fmnt, language=language)

            output_file_path = os.path.join(valence_output_path, f"{filename.rstrip('.jsonl')}_valence.jsonl")
            os.makedirs(valence_output_path, exist_ok=True)  # Assicurati che la directory esista

            with open(output_file_path, 'a') as out_file:
                for i in range(1000):
                    if i % 50 == 0:
                        print(i)
                    random_positive, random_negative, random_neutral = swap_elements_in_sets(positive, negative, neutral)
                    
                    def get_random_valence(word):
                        if word in random_positive:
                            return 'positive'
                        elif word in random_negative:
                            return 'negative'
                        else:
                            return 'neutral'
                    
                    # Weighted network analysis
                    random_weights = {
                        'pos_pos': 0, 'pos_neutral': 0, 'neg_neutral': 0,
                        'neg_neg': 0, 'neutral_neutral': 0, 'pos_neg': 0,
                        'weight_pos_pos': 0, 'weight_pos_neutral': 0, 'weight_neg_neutral': 0,
                        'weight_neg_neg': 0, 'weight_neutral_neutral': 0, 'weight_pos_neg': 0
                    }
        
                    for node1, node2, weight in weighted_fmnt:
                        random_valence1, random_valence2 = get_random_valence(node1), get_random_valence(node2)
            
                        # Random distribution
                        if random_valence1 == 'positive' and random_valence2 == 'positive':
                            random_weights['pos_pos'] += 1
                            random_weights['weight_pos_pos'] += weight
                        elif (random_valence1 == 'positive' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'positive'):
                            random_weights['pos_neutral'] += 1
                            random_weights['weight_pos_neutral'] += weight
                        elif (random_valence1 == 'negative' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'negative'):
                            random_weights['neg_neutral'] += 1
                            random_weights['weight_neg_neutral'] += weight
                        elif random_valence1 == 'negative' and random_valence2 == 'negative':
                            random_weights['neg_neg'] += 1
                            random_weights['weight_neg_neg'] += weight
                        elif random_valence1 == 'neutral' and random_valence2 == 'neutral':
                            random_weights['neutral_neutral'] += 1
                            random_weights['weight_neutral_neutral'] += weight
                        elif (random_valence1 == 'negative' and random_valence2 == 'positive') or (random_valence1 == 'positive' and random_valence2 == 'negative'):
                            random_weights['pos_neg'] += 1
                            random_weights['weight_pos_neg'] += weight
                        
                    json.dump(random_weights, out_file)
                    out_file.write('\n')
                    out_file.flush()
                    
export_loop_valences()
# Out:
# GPT-3.5(ITA)
# wtf: {'professionista', 'entità', 'combinazione', 'compromesso', 'paranoia', 'spaventare', 'allontanare', 'superstizione', 'manipolatoria', 'revisione', 'scoraggiandole', 'epoca', 'anonimato', 'sero', 'precauzione', 'anziano', 'prolungare', 'compromettono', 'pagare', 'acriticità', 'tentacolario', 'combattere', 'imprudenza', 'ciarlatano', 'combattere lo', 'bello', 'competenza', 'collaborazione', 'consultare', 'letale', 'liberamente', 'personalmente', 'preservare', 'rimanere', 'analizzare', 'vaccinare', 'contrasto', 'sviare', 'puntare', 'sacrificare', 'sensibilizzira', 'manipolativo', 'imbattere si', 'bombardare', 'antivaccinismo', 'mare', 'naturale', 'chiedere si', 'produrre', 'compromuevere', 'olio', 'avvere si', 'contagioso', 'trattare', 'conseguente', 'economico', 'uso', 'punto', 'prevale', 'presupposta', 'proposta', 'seguire li', 'lesione', 'soluzione', 'derivare', 'contraddittorio', 'prontamente', 'dedicare', 'irrigidere', 'avvenimento', 'evidenziare', 'aggiornato', 'ergere', 'assumere si', 'imparare', 'rischare', 'attirare', 'sito', 'urgente', 'veicolo', 'scioccante', 'distortre', 'eradico', 'basira', 'combatteo', 'piano', 'diffondendole', 'scapito', 'passaggio', 'Goverantive', 'negare la', 'mascherare', 'percorso', 'riflessivo', 'procedimento', 'fornire', 'instancabilmente', 'basare si', 'civile', 'metodo', 'accessibile', 'fondato', 'invitare', 'documentato', 'attivo', 'narrazione', 'manipolatore', 'ritardo', 'epidemico', 'difendere', 'parola', 'trarre ne', 'sottoponere', 'demonizzare', 'questione', 'attingiare', 'alimento', 'ignoralza', 'deliberata', 'privilegiare', 'farmacologico', 'esitazione', 'critica', 'metodologico', 'veritiere', 'condividere le', 'instabile', 'accompagnare', 'smettiamolare', 'rigido', 'concentrare si', 'esistere', 'orientare si', 'sperimentale', 'smascherare', 'dialogo', 'costruzione', 'frenare', 'desiderare', 'moltitudine', 'cocktail', 'sottolineare', 'empatia', 'fallace', 'negligente', 'serissimo', 'comunicazione', 'apparenza', 'mistero', 'impatto', 'aderire', 'mettere le', 'politico', 'dito', 'salverebbero', 'offrere', 'crisi', 'ricordiamoci', 'luce', 'offrire', 'creare', 'ansia', 'costantemente', 'crescere', 'evidente', 'irreversibile', 'deprecabile', 'rilevante', 'affidamento', 'credere ci', 'conducendole', 'riscontro', 'politica', 'fittizio', 'ritardare', 'cerchare', 'patrimonio', 'convinzione', 'malefico', 'linea', 'sostenere', 'stigmatizzazione', 'sostituere lo', 'riconoscere', 'preferere', 'cambiare', 'disposto', 'aneddotico', 'decisione', 'paranoico', 'ricevano', 'comprensione', 'enormemente', 'raffinare', 'minare lo', 'cancro', 'preferire', 'spirito', 'immune', 'chiaramente', 'suscettibilità', 'pertanto', 'sensibilizzazione', 'medicina', 'area', 'salute', 'eradicare', 'avanzato', 'radice', 'caratteristica', 'concreto', 'autoritario', 'nascondere', 'comunemente', 'combattute', 'restare', 'affrontare', 'educativo', 'biologia', 'insensare', 'assumere ci', 'costoso', 'palese', 'raccomandato', 'contemporaneo', 'divisione', 'élite', 'ostile', 'unito', 'occhio', 'malevole', 'literacy', 'protetto', 'ricadere', 'complottistico', 'motivare', 'professionale', 'congettura', 'farfugliato', 'circostante', 'osservare', 'alzare', 'screditare', 'tensione', 'riuscire', 'protocollo', 'danneggiare ci', 'reputazionale', 'assicurare ci', 'ignorare le', 'accento', 'resistenza', 'disperatamente', 'science', 'irreparabile', 'prezioso', 'educatore', 'diffusesenza', 'deprimente', 'servizio', 'convenzionale', 'newsre', 'correttezza', 'vizioso', 'intento', 'filtrare', 'impegnare', 'discredito', 'seguire le', 'prendere', 'raccomandare', 'soggetto', 'economia', 'permettere lo', 'esprimere', 'esistente', 'irresponsabile', 'timore', 'accusa', 'ciecamente', 'gestione', 'comprovare', 'arma', 'credulone', 'ragionevole', 'illazione', 'unico', 'intelligente', 'bloccare', 'semplificato', 'inevitabilmente', 'misura', 'coraggio', 'bisogno', 'salutare', 'cultura', 'difendere lo', 'fuorviare', 'pubblicazione', 'inventare', 'uti ...
# {'assoluto', 'affermazione', 'approvare', 'stabilito', 'innovazione', 'suscettibile', 'progresso', 'precauzione', 'auspicabile', 'ambiente', 'pagare', 'desideroso', 'bello', 'dichiarazione', 'vigile', 'competenza', 'governativo', 'collaborazione', 'resistere', 'forte', 'informazione', 'liberamente', 'ritmo', 'caro', 'consapevole', 'credibilità', 'contribuire', 'consapevolezza', 'vaccino', 'coerenza', 'volontà', 'reciproco', 'robusto', 'pubblico', 'mare', 'centro', 'produrre', 'certezza', 'punto', 'soluzione', 'prontamente', 'giovane', 'educare', 'livello', 'presenza', 'fedele', 'tentativo', 'imparare', 'innocuo', 'minore', 'scherzare', 'professione', 'pilastro', 'fornire', 'salvaguardia', 'civile', 'medico', 'accessibile', 'invitare', 'tendenza', 'scelta', 'ricevuto', 'antidoto', 'difendere', 'parola', 'procedura', 'massimo', 'critica', 'zelante', 'semplice', 'parlare', 'sviluppare', 'prevedere', 'ampio', 'assicurare', 'impegno', 'costruzione', 'cruciale', 'equilibrato', 'sottolineare', 'empatia', 'utilità', 'igienico', 'prevenzione', 'notevole', 'veridicità', 'guadagno', 'maggiore', 'politico', 'capacità', 'tradizionale', 'difesa', 'superiore', 'creare', 'senso', 'crescere', 'offerta', 'evidente', 'dimostrabile', 'affidamento', 'straordinario', 'miracoloso', 'contare', 'accademico', 'sostenere', 'esistenza', 'amico', 'ricercatore', 'società', 'aumento', 'disposto', 'guadagnare', 'volontario', 'affetto', 'negoziare', 'comprensione', 'nutrire', 'influente', 'discussione', 'preferire', 'completamente', 'spirito', 'ricevere', 'familiare', 'chiarezza', 'vigore', 'caratteristica', 'supporto', 'educativo', 'fermezza', 'giusto', 'scienziato', 'unito', 'bambino', 'etica', 'ripresa', 'assumere', 'professionale', 'discorso', 'costante', 'sforzo', 'perpetuo', 'motivo', 'resistenza', 'guarire', 'rafforzare', 'fantasioso', 'prezioso', 'incoraggiare', 'facilitare', 'regolare', 'ministero', 'merito', 'efficace', 'convincente', 'solido', 'azione', 'gestione', 'sostenitore', 'abbondante', 'unico', 'pillola', 'intelligente', 'seriamente', 'contatto', 'costruire', 'includere', 'guardiano', 'prevalere', 'coraggio', 'doveroso', 'salutare', 'cultura', 'coltivare', 'ricerca', 'leva', 'tecnologia', 'educato', 'guru', 'autentico', 'canto', 'affidabile', 'magico', 'cittadino', 'etico', 'verificato', 'migliorare', 'amare', 'attento', 'fertile', 'accettazione', 'lettura', 'credito', 'credibile', 'scientifico', 'salvezza', 'paziente', 'guardia', 'logico', 'accreditato', 'apertura', 'interesse', 'efficacia', 'morale', 'civiltà', 'fondamentale', 'istruire', 'costanza', 'gestire', 'tutela', 'esperto', 'resiliente', 'forma', 'fantasia', 'compiere', 'popolazione', 'umano', 'deliberato', 'successo', 'abilità', 'intelligenza', 'comunicare', 'contenuto', 'vero', 'suscitare', 'garantire', 'beneficio', 'aiutare', 'raggiungere', 'terapeutico', 'proteggere', 'rispetto', 'sostanza', 'legittimo', 'potenza', 'rispettoso', 'fiducia', 'serietà', 'cooperazione', 'convincere', 'salvare', 'insegnare', 'razionale', 'intellettuale', 'tipo', 'passione', 'libertà', 'vantaggio', 'consigliare', 'valore', 'sanitario', 'compito', 'scoperta', 'importante', 'guida', 'ispirare', 'lusso', 'sano', 'competente', 'raggiungimento', 'curabile', 'occupare', 'tempestivo', 'fortemente', 'vittoria', 'istruzione', 'autorità', 'teorico', 'umanità', 'rimedio', 'miglioramento', 'determinato', 'solidità', 'aspettativa', 'promettere', 'fondare', 'verità', 'conoscenza', 'sensazionale', 'alleato', 'rapidità', 'nascita', 'rendere', 'domanda', 'completo', 'interessante', 'difensore', 'superare', 'alimentazione', 'assistere', 'prossimo', 'sicuro', 'corretto', 'aumentare', 'saggezza', 'esortare', 'verifica', 'interessato', 'promozione', 'comprendere', 'organizzazione', 'responsabile', 'produzione', 'visione', 'infallibile', 'preciso', 'risalto', 'illimitato', 'farmaceutico', 'diffondere', 'meritare', 'preparato', 'serio', 'speranza', 'ricostruzione', 'principale', 'autorizzato', 'collettivamente', 'studioso ...
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# GPT-3.5
# wtf: {'overlook', 'especially', 'lethal', 'caution', 'aware', 'care', 'paranoia', 'conscientious', 'deluge', 'viewpoint', 'problematic', 'basic', 'pertain', 'channel', 'responsibility', 'stance', 'righteous', 'like', 'government', 'link', 'promote', 'true', 'monetization', 'basis', 'worldwide', 'hyperconnected', 'cycle', 'fad', 'fast', 'hole', 'curiosity', 'leader', 'fabric', 'account', 'drastic', 'consumer', 'bad', 'exacerbate', 'onus', 'existing', 'debunking', 'resort', 'inappropriate', 'injury', 'ignore', 'foregone', 'disease', 'manage', 'necessarily', 'prominence', 'decisive', 'addition', 'embrace', 'spreading', 'forego', 'breakdown', 'flag', 'promotion', 'natural', 'loop', 'bridge', 'trust', 'medically', 'result', 'scientifically', 'measle', 'not-encounter', 'consciousness', 'advantage', 'flood', 'sensationalized', 'second', 'prescribed', 'million', 'citizen', 'minimize', 'analysis', 'persistent', 'challenge', 'field', 'reluctant', 'desperation', 'disability', 'difference', 'plot', 'alarming', 'money', 'unhealthy', 'illusion', 'proven', 'understandable', 'weaken', 'little', 'extremely', 'rapidly', 'chaotic', 'uneasy', 'resource', 'product', 'reason', 'massive', 'age', 'typically', 'global', 'inform', 'regulate', 'enable', 'extent', 'unsupported', 'dedicate', 'combine', 'offer', 'guidance', 'unbiased', 'research', 'evaluation', 'misunderstanding', 'advice', 'insight', 'injustice', 'condition', 'instant', 'pervasive', 'significant', 'unchecked', 'myth', 'appropriately', 'certain', 'sensationalistic', 'connectivity', 'unvalidated', 'concise', 'pronged', 'new', 'push', 'achieve', 'foundation', 'interaction', 'monitor', 'motivated', 'prove', 'accountable', 'help', 'eschew', 'reputation', 'pursuit', 'not-vaccinated', 'journalist', 'crisis', 'hinder', 'correct', 'manufacture', 'flagging', 'widespread', 'curate', 'personal', 'dissemination', 'evident', 'immune', 'mean', 'captivate', 'suffer', 'evolve', 'ideology', 'outweigh', 'area', 'design', 'expose', 'troublesome', 'participate', 'desperate', 'overcome', 'youtube', 'complicate', 'stand', 'susceptible', 'improve', 'noncompliance', 'economic', 'presence', 'order', 'governance', 'frame', 'mouth', 'guide', 'ill', 'literacy', 'datum', 'distrust', 'behavior', 'way', 'bombard', 'masquerade', 'we', 'gap', 'outbreak', 'rampant', 'entice', 'dismissive', 'connect', 'travel', 'immediate', 'science', 'false', 'grow', 'vast', 'widely', 'fall', 'let', 'conflicting', 'ongoing', 'turn', 'snowball', 'arena', 'scarce', 'steer', 'paper', 'mismanagement', 'not-prevalent', 'meaningful', 'constantly', 'major', 'overly', 'include', 'tragic', 'tirelessly', 'child', 'assess', 'personally', 'factually', 'overwhelmed', 'catastrophic', 'compliance', 'untested', 'pervasiveness', 'deter', 'certainly', 'disrupt', 'biologically', 'stress', 'harmless', 'precious', 'equipped', 'incumbent', 'disastrous', 'confusion', 'possess', 'vaccine', 'crucial', 'fringe', 'shield', 'deny', 'communication', 'enticing', 'dimension', 'stringent', 'not-cloud', 'big', 'mask', 'indicate', 'certainty', 'accuracy', 'develop', 'diligently', 'domain', 'inclusivity', 'undermine', 'firstly', 'overall', 'institutional', 'campaign', 'skip', 'context', 'strengthen', 'surround', 'answer', 'benefit', 'term', 'interest', 'mistrust', 'potential', 'source', 'pose', 'sea', 'reliable', 'sensitive', 'misinformed', 'vaccinated', 'disenfranchisement', 'wear', 'lure', 'refusal', 'cohesion', 'currently', 'air', 'damaging', 'reverse', 'main', 'curb', 'trusted', 'confidence', 'established', 'existent', 'expert', 'conspire', 'medicate', 'restore', 'conclusion', 'reduce', 'perceive', 'essential', 'safeguard', 'assistance', 'skepticism', 'quality', 'platform', 'foundational', 'appeal', 'interconnect', 'comprehensive', 'think', 'skill', 'allocate', 'flourish', 'cognitive', 'open', 'site', 'relevant', 'consider', 'reporting', 'outreach', 'country', 'empower', 'exploit', 'theorist', 'compromise', 'change', 'worker', 'center', 'positive', 'unreal', 'cultivate' ...
# {'compassion', 'verification', 'acceptance', 'speech', 'understanding', 'valuable', 'clarify', 'fully', 'prevail', 'deliberate', 'major', 'friend', 'delivery', 'build', 'include', 'choice', 'committed', 'child', 'pertinent', 'deal', 'vital', 'study', 'continue', 'create', 'immense', 'option', 'merit', 'respect', 'reputable', 'existence', 'conscientious', 'compliance', 'healthy', 'organization', 'partnership', 'community', 'authoritative', 'adept', 'helper', 'structure', 'hope', 'steadfast', 'afford', 'freedom', 'important', 'doctor', 'righteous', 'precious', 'contribute', 'fertile', 'fundamental', 'motive', 'traditional', 'associate', 'protect', 'determination', 'achieve', 'foundation', 'constant', 'allure', 'possess', 'sensational', 'vaccine', 'crucial', 'alluring', 'discussion', 'unity', 'truthfulness', 'word', 'prove', 'accountable', 'credential', 'integrity', 'sincerity', 'attention', 'curiosity', 'leader', 'culture', 'balanced', 'inquiry', 'flow', 'persistence', 'advance', 'academic', 'journalist', 'certainty', 'ethical', 'substance', 'promise', 'equity', 'develop', 'complacency', 'widespread', 'educational', 'convenient', 'vigilant', 'rational', 'credible', 'efficacy', 'respectful', 'expectation', 'police', 'reassurance', 'share', 'sincere', 'credibility', 'present', 'accountability', 'willingness', 'evident', 'advocacy', 'influential', 'equally', 'moral', 'captivate', 'level', 'strengthen', 'manage', 'considerable', 'corroborate', 'scientific', 'accessible', 'prominence', 'benefit', 'verified', 'embrace', 'interest', 'building', 'blessing', 'accurate', 'safe', 'promotion', 'effort', 'prevention', 'assist', 'cooperation', 'compassionate', 'management', 'sea', 'advancement', 'reinforcement', 'responsible', 'professional', 'reliable', 'population', 'productive', 'shape', 'champion', 'task', 'save', 'abundant', 'improve', 'real', 'dedication', 'lead', 'knowledge', 'presence', 'helpful', 'proper', 'powerful', 'ability', 'moderate', 'thinker', 'authentic', 'sense', 'provide', 'betterment', 'completely', 'guide', 'progress', 'consciousness', 'timely', 'advantage', 'facilitate', 'faith', 'qualified', 'trend', 'mindful', 'medical', 'primary', 'notion', 'nurture', 'readily', 'leverage', 'ultimately', 'exchange', 'govern', 'citizen', 'career', 'main', 'improved', 'united', 'patient', 'confidence', 'persistent', 'established', 'expertise', 'gain', 'actual', 'array', 'genuine', 'found', 'cautious', 'detect', 'expert', 'solid', 'objective', 'increase', 'truth', 'openness', 'perceive', 'miracle', 'happy', 'dietary', 'encourage', 'unequivocally', 'ease', 'question', 'growth', 'essential', 'disseminate', 'money', 'love', 'partner', 'bolster', 'safeguard', 'grow', 'assistance', 'enhance', 'practice', 'prepare', 'overwhelming', 'preserve', 'comprehensive', 'solution', 'pharmaceutical', 'good', 'compelling', 'action', 'focus', 'procedure', 'convince', 'cognitive', 'strongly', 'importance', 'effective', 'reason', 'reliance', 'reliability', 'logical', 'wealth', 'pick', 'relevant', 'resilient', 'opportunity', 'general', 'authority', 'precision', 'honest', 'teach', 'learn', 'empathy', 'collectively', 'young', 'deserve', 'beneficial', 'precaution', 'invariably', 'regulate', 'candid', 'enable', 'empower', 'vigilance', 'endeavor', 'cascade', 'extend', 'worth', 'robust', 'scientist', 'communicate', 'participation', 'miraculous', 'center', 'cherry', 'educate', 'offer', 'core', 'paramount', 'cultivate', 'recommend', 'guidance', 'unbiased', 'public', 'recovery', 'technology', 'careful', 'prosperity', 'outcome', 'content', 'corporation', 'information', 'remedy', 'diligence', 'honesty'}
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400

# %% [markdown]
# # Utilities

# %%
def valence_metrics(weighted_network, model, topic, language='english'):
    
    positive, negative, neutral = get_valence_sets(weighted_network, language=language)
    random_positive, random_negative, random_neutral = swap_elements_in_sets(positive, negative, neutral)

    def get_valence(word):
        if word in positive:
            return 'positive'
        elif word in negative:
            return 'negative'
        else:
            return 'neutral'
        
    def get_random_valence(word):
        if word in random_positive:
            return 'positive'
        elif word in random_negative:
            return 'negative'
        else:
            return 'neutral'

    # Weighted network analysis
    weight_pos_pos, weight_pos_neutral, weight_pos_neg,weight_neg_neutral, weight_neg_neg, weight_neutral_neutral = 0, 0, 0, 0, 0, 0
    random_weight_pos_pos, random_weight_pos_neutral, random_weight_pos_neg, random_weight_neg_neutral, random_weight_neg_neg, random_weight_neutral_neutral = 0, 0, 0, 0, 0, 0
    
    for node1, node2, weight in weighted_network:
        valence1, valence2 = get_valence(node1), get_valence(node2)
        random_valence1, random_valence2 = get_random_valence(node1), get_random_valence(node2)
        
        # Normal distribution
        if valence1 == 'positive' and valence2 == 'positive':
            weight_pos_pos += weight
        elif (valence1 == 'positive' and valence2 == 'neutral') or (valence1 == 'neutral' and valence2 == 'positive'):
            weight_pos_neutral += weight
        elif (valence1 == 'negative' and valence2 == 'neutral') or (valence1 == 'neutral' and valence2 == 'negative'):
            weight_neg_neutral += weight
        elif valence1 == 'negative' and valence2 == 'negative':
            weight_neg_neg += weight
        elif valence1 == 'neutral' and valence2 == 'neutral':
            weight_neutral_neutral += weight
        elif (valence1 == 'negative' and valence2 == 'positive') or (valence1 == 'positive' and valence2 == 'negative'):
            weight_pos_neg += weight
        
        # Random distribution
        if random_valence1 == 'positive' and random_valence2 == 'positive':
            random_weight_pos_pos += weight
        elif (random_valence1 == 'positive' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'positive'):
            random_weight_pos_neutral += weight
        elif (random_valence1 == 'negative' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'negative'):
            random_weight_neg_neutral += weight
        elif random_valence1 == 'negative' and random_valence2 == 'negative':
            random_weight_neg_neg += weight
        elif random_valence1 == 'neutral' and random_valence2 == 'neutral':
            random_weight_neutral_neutral += weight
        elif (random_valence1 == 'negative' and random_valence2 == 'positive') or (random_valence1 == 'positive' and random_valence2 == 'negative'):
            random_weight_pos_neg += weight
    
    print("\nWeighted Network Metrics:")
    print(f"Total weight of edges between positive nodes: {weight_pos_pos}")
    print(f"Total weight of edges between positive and neutral nodes: {weight_pos_neutral}")
    print(f"Total weight of edges between negative and neutral nodes: {weight_neg_neutral}")
    print(f"Total weight of edges between negative nodes: {weight_neg_neg}")
    print(f"Total weight of edges between neutral nodes: {weight_neutral_neutral}")
    print(f"Total weight of edges between contrasting nodes: {weight_pos_neg}")
    
    print("\nRandom Distribution Metrics:")
    print(f"Total weight of edges between positive nodes: {random_weight_pos_pos}")
    print(f"Total weight of edges between positive and neutral nodes: {random_weight_pos_neutral}")
    print(f"Total weight of edges between negative and neutral nodes: {random_weight_neg_neutral}")
    print(f"Total weight of edges between negative nodes: {random_weight_neg_neg}")
    print(f"Total weight of edges between neutral nodes: {random_weight_neutral_neutral}")
    print(f"Total weight of edges between contrasting nodes: {random_weight_pos_neg}")
    
    # Calculate z-scores
    normal_weights = [weight_pos_pos, weight_pos_neutral, weight_neg_neutral, weight_neg_neg, weight_neutral_neutral,weight_pos_neg]
    random_weights = [random_weight_pos_pos, random_weight_pos_neutral, random_weight_neg_neutral, random_weight_neg_neg, random_weight_neutral_neutral,random_weight_pos_neg]
    
    z_scores = stats.zscore(normal_weights + random_weights)[:len(normal_weights)]
    
    print("\nZ-scores (Normal vs Random):")
    for label, z_score in zip(['Positive-Positive', 'Positive-Neutral', 'Negative-Neutral', 'Negative-Negative', 'Neutral-Neutral','Positive-Negative'], z_scores):
        print(f"{label}: {z_score:.2f}")
    
    # Plotting
    labels = ['Positive-Positive', 'Positive-Neutral', 'Negative-Neutral', 'Negative-Negative', 'Neutral-Neutral','Positive-Negative']
    normal_sizes = normal_weights
    random_sizes = random_weights
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
    
    ax1.pie(normal_sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    ax1.set_title('Normal Valence Distribution')
    
    ax2.pie(random_sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    ax2.set_title('Random Valence Distribution')
    
    plt.suptitle(f'Distribution of Edge Weights by Node Valence for model {model} and topic {topic}: Normal vs Random')
    plt.show()
# Example usage:

#valence_metrics(w_fmnt,'Haiku','climate')

# %%
for folder in folders_of_interest:
    folder_path = os.path.join(base_output_dir, folder)

    for filename in os.listdir(folder_path):
        #print(filename.rstrip('.jsonl'))

        if '(ITA)' in filename:
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                
                fmnts=[]

                for line in file:
                    data = json.loads(line)
                    fmnts.append(data['fmnt']['syntactic'])
                weighted_fmnt = emos.combine_edgelists(fmnts)
                print(len(weighted_fmnt))
                print(weighted_fmnt[0])
                valence_metrics(weighted_fmnt,filename.rstrip('.jsonl'),folder,language='italian')
