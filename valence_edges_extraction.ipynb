# %%
from emoatlas import EmoScores
import os
import json
import re
from pprint import pprint
from collections import defaultdict
from emoatlas.resources import _valences
import random
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats



emos=EmoScores()

# %%
base_output_dir = "localdb"
valence_dir = "Valence_Metrics"

# Folders of interest
folders_of_interest = ['climate', 'math', 'misinformation_health','gwarming']
folders_of_interest = ['misinformation_health']

# %%
def extract_model(filename):
    if filename.endswith('.jsonl'):
        return filename[:-6]  # Remove the last 6 characters
    else:
        return filename

# %%
def get_valence_sets(weighted_fmnt, language='english'):
    
    positive, negative, ambivalent = _valences(language)
    

    all_nodes = set(node for edge in weighted_fmnt for node in edge[:2])

    print('wtf:', all_nodes)



    positive_nodes = all_nodes.intersection(positive)
    print(positive_nodes)
    negative_nodes = all_nodes.intersection(negative)
    neutral_nodes = all_nodes - (positive_nodes | negative_nodes )

    return positive_nodes, negative_nodes, neutral_nodes

# %%
def swap_elements_in_sets(set1, set2, set3):
    # Calculate total number of elements
    total_elements = len(set1) + len(set2) + len(set3)
    
    # Convert sets to lists for easy manipulation
    lists = [list(set1), list(set2), list(set3)]
    
    # Perform swapping operations
    for _ in range(10 * total_elements):
        # Pick 2 random sets without repetition
        set_indices = random.sample(range(3), 2)
        
        # Pick a random word from each set
        word1 = random.choice(lists[set_indices[0]])
        word2 = random.choice(lists[set_indices[1]])
        
        # Only swap if the words don't already exist in the other list
        if word1 not in lists[set_indices[1]] and word2 not in lists[set_indices[0]]:
            lists[set_indices[0]].remove(word1)
            lists[set_indices[1]].remove(word2)
            lists[set_indices[0]].append(word2)
            lists[set_indices[1]].append(word1)
    
    # Convert lists back to sets
    return set(lists[0]), set(lists[1]), set(lists[2])

# %%
def export_loop_valences():
    for folder in folders_of_interest:
        input_folder_path = os.path.join(base_output_dir, folder)
        valence_output_path = os.path.join(valence_dir, folder)

        for filename in os.listdir(input_folder_path):
            print(filename.rstrip('.jsonl'))

            file_path = os.path.join(input_folder_path, filename)
            with open(file_path, 'r') as file:
                fmnts = []
                for line in file:
                    data = json.loads(line)
                    fmnts.append(data['fmnt']['syntactic'])
            
            weighted_fmnt = emos.combine_formamentis(fmnts, weights=True)
            if 'ITA' in filename:
                language = 'italian'
            else:
                language = 'english'

            positive, negative, neutral = get_valence_sets(weighted_fmnt, language=language)

            output_file_path = os.path.join(valence_output_path, f"{filename.rstrip('.jsonl')}_valence.jsonl")
            os.makedirs(valence_output_path, exist_ok=True)  # Assicurati che la directory esista

            with open(output_file_path, 'a') as out_file:
                for i in range(1000):
                    if i % 50 == 0:
                        print(i)
                    random_positive, random_negative, random_neutral = swap_elements_in_sets(positive, negative, neutral)
                    
                    def get_random_valence(word):
                        if word in random_positive:
                            return 'positive'
                        elif word in random_negative:
                            return 'negative'
                        else:
                            return 'neutral'
                    
                    # Weighted network analysis
                    random_weights = {
                        'pos_pos': 0, 'pos_neutral': 0, 'neg_neutral': 0,
                        'neg_neg': 0, 'neutral_neutral': 0, 'pos_neg': 0,
                        'weight_pos_pos': 0, 'weight_pos_neutral': 0, 'weight_neg_neutral': 0,
                        'weight_neg_neg': 0, 'weight_neutral_neutral': 0, 'weight_pos_neg': 0
                    }
        
                    for node1, node2, weight in weighted_fmnt:
                        random_valence1, random_valence2 = get_random_valence(node1), get_random_valence(node2)
            
                        # Random distribution
                        if random_valence1 == 'positive' and random_valence2 == 'positive':
                            random_weights['pos_pos'] += 1
                            random_weights['weight_pos_pos'] += weight
                        elif (random_valence1 == 'positive' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'positive'):
                            random_weights['pos_neutral'] += 1
                            random_weights['weight_pos_neutral'] += weight
                        elif (random_valence1 == 'negative' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'negative'):
                            random_weights['neg_neutral'] += 1
                            random_weights['weight_neg_neutral'] += weight
                        elif random_valence1 == 'negative' and random_valence2 == 'negative':
                            random_weights['neg_neg'] += 1
                            random_weights['weight_neg_neg'] += weight
                        elif random_valence1 == 'neutral' and random_valence2 == 'neutral':
                            random_weights['neutral_neutral'] += 1
                            random_weights['weight_neutral_neutral'] += weight
                        elif (random_valence1 == 'negative' and random_valence2 == 'positive') or (random_valence1 == 'positive' and random_valence2 == 'negative'):
                            random_weights['pos_neg'] += 1
                            random_weights['weight_pos_neg'] += weight
                        
                    json.dump(random_weights, out_file)
                    out_file.write('\n')
                    out_file.flush()
                    
export_loop_valences()
# Out:
# GPT-3.5(ITA)
# wtf: {'spingere lo', 'protrare si', 'sicuro', 'isteria', 'commettere', 'saggio', 'mancare', 'economicamente', 'ricetta', 'necessità', 'veloce', 'compreso', 'credenza', 'anziché', 'sciocco', 'coronavirus', 'coinvolgere', 'inevitabilmente', 'documentandoci', 'sviare', 'indirettamente', 'scaturire', 'riportare', 'denaro', 'capace', 'sfidare', 'addestrare', 'morale', 'pubblicizzare', 'affievolimento', 'fertile', 'distolgono', 'apparentemente', 'demagogico', 'positivo', 'crescere', 'sorprendente', 'emergenza', 'seguire le', 'valenza', 'offline', 'nascondere', 'costringere lo', 'congiunto', 'rischiare', 'luce', 'rassicurante', 'pharma', 'compromettare', 'permettere si', 'guida', 'mancato', 'diffondono', 'vulnerabile', 'salvaguardia', 'formulare', 'disuguaglianza', 'democratico', 'rigido', 'base', 'semplicemente', 'fisiologico', 'quotidiano', 'vittoria', 'seguire la', 'egoistico', 'Mainstream', 'disprezzo', 'discorso', 'espongere', 'difendere lo', 'mediatico', 'prezzo', 'metropolitano', 'enfasi', 'dinamica', 'seguire', 'giornalismo', 'scevre ra', 'consulare', 'manipolare', 'ricordiamoci', 'difendere li', 'artefice', 'condizionare', 'epoca', 'avvenimento', 'diffudere', 'rivista', 'pagare', 'completo', 'privilegiare', 'industria', 'valutare', 'risolutezza', 'disinformatore', 'alimentazione', 'guardare', 'spiegazione', 'significativo', 'bussola', 'testimonianza', 'aggravare si', 'assurdo', 'negare la', 'magico', 'difendere', 'preferere', 'raccogliere', 'squilibrato', 'speranza', 'educato', 'distriro', 'chiarezza', 'trovare', 'distorta', 'rigoroso', 'seme', 'ripetut
', 'achieve', 'rational', 'building', 'happy', 'educational', 'confidence', 'truth', 'general', 'moral', 'sense', 'honest', 'champion', 'steadfast', 'pharmaceutical', 'miraculous', 'reliable', 'possess', 'evident', 'overwhelming', 'knowledge', 'expert', 'vigilant', 'reliance', 'expectation', 'strengthen', 'ultimately', 'safe', 'build', 'abundant', 'reassurance', 'accountable', 'pertinent', 'offer', 'expertise', 'partnership', 'sensational', 'valuable', 'effective', 'sincere', 'disseminate', 'authentic', 'share', 'increase', 'information', 'center', 'nurture', 'educate', 'promotion', 'honesty', 'resilient', 'healthy', 'police', 'remedy', 'task', 'freedom', 'core', 'openness', 'certainty', 'convenient', 'solution', 'integrity', 'grow', 'proper', 'scientist', 'scientific', 'academic', 'word', 'efficacy', 'helper', 'existence', 'complacency', 'persistence', 'associate', 'clarify', 'respect', 'trend', 'option', 'doctor', 'alluring', 'captivate', 'cherry', 'importance', 'assistance', 'precision', 'considerable', 'attention', 'dedication', 'important', 'sincerity', 'exchange', 'powerful', 'fundamental', 'cooperation', 'accessible', 'communicate', 'recovery', 'consciousness', 'facilitate', 'moderate', 'equally', 'logical', 'good', 'embrace', 'merit', 'citizen', 'learn', 'unity', 'reinforcement', 'genuine', 'continue', 'ability', 'public', 'productive', 'credibility', 'career', 'vital', 'contribute', 'equity', 'present', 'convince', 'prevention', 'child', 'strongly', 'advocacy', 'hope', 'patient', 'extend', 'guidance', 'endeavor', 'advantage', 'authority', 'vaccine', 'essential', 'preserve', 'benefit', 'improved', 'mindful', 'leader', 'deserve', 'safeguard', 'journalist', 'actual', 'diligence', 'compassion', 'interest', 'dietary', 'primary', 'create', 'united', 'leverage', 'prominence', 'guide', 'real', 'include', 'unequivocally', 'cultivate', 'righteous', 'action'}
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# GPT-4o(ITA)
# wtf: {'escluse', 'culturale', 'garane ti', 'smarrire', 'diere', 'necessità', 'compreso', 'anziché', 'banalizzare', 'aggravamento', 'stravagante', 'commercializzare', 'comportamentale', 'autoproclamare', 'travestono', 'capace', 'multidimensionale', 'recupero', 'sentire ci', 'autoproclamatidere', 'fertile', 'apparentemente', 'perpetrare', 'allineare', 'crescere', 'sottilmente', 'madornale', 'difetto', 'incompetente', 'congiunto', 'amplificira ne', 'rassicurante', 'obbligo', 'pharma', 'globalizzazione', 'gap', 'subire', 'alimentare si', 'contemporaneamente', 'salvaguardia', 'laboratorio', 'disinformativo', 'accountability', 'sfuggente', 'compromettere ne', 'base', 'semplicemente', 'condizionamento', 'prescritto', 'ignorabile', 'quotidiano', 'elaborare la', 'subire ne', 'determinante', 'disprezzo', 'discorso', 'rivestere', 'mediatico', 'giornalismo', 'conformità', 'algoritimico', 'radicamento', 'epoca', 'sottile', 'completo', 'spiegazione', 'significativo', 'disagio', 'ecc.', 'bussola', 'ritirato', 'testimonianza', 'insoddisfazione', 'chiudono', 'magico', 'difendere', 'complementare', 'indebitamente', 'raccogliere', 'speranza', 'distriro', 'casuale', 'convivere', 'potenziare', 'combinato', 'condiscendenza', 'operare', 'decisi', 'ridicolizzare', 'fact', 'ingegno', 'trasversale', 'comune', 'scontrare', 'nicchia', 'rinfiuto', 'intessere', 'carismatico', 'ridicolo', 'resistere', 'espandere', 'imparziale', 'promosso', 'their', 'supposto', 'scrupoloso', 'condiviso', 'armare', 'aiutare le', 'interferere', 'vigore', 'cambiare le', 'riapparizione', 'astratto', 'impegnato', 'alterazione', 'manipolatoria', 'controcorrente', 'miracolo', 'cadano', 'largamente', 'credito', 'benefica', 'ridurre', 'governativo', 'contrastare le', 'pesantemente', 'contratto', 'offrere', 'ritorno', 'pregresso', 'eccessivamente', 'skepticism', 'factual', 'ingloba', 'apparenza', 'popolazione', 'ignoto', 'coinvolgere si', 'suggerimento', 'sconfitta', 'multifaccettata', 'legame', 'scientificamente', 'estinte', 'accesso', 'responsivo', 'ledere', 'eroico', 'assistere', 'prediligere', 'investigare', 'credano', 'focale', 'influencers', 'ascolto', 'raggio', 'lineare', 'intrigo', 'rispettare', 'infografica', 'eradicazione', 'contraddizione', 'agevolare', 'adattativo', 'appoggio', 'descrivere', 'avvalere', 'drammatizzare', 'sensibilizzare', 'trascendere', 'straordinariamente', 'investare', 'puttosto', 'impiego', 'avvolre', 'costringere', 'costringere li', 'propagatore', 'area', 'discordia', 'sottovalutazione', 'insalubro', 'flusso', 'potenzialità', 'velocità', 'rischio', 'corretre', 'interculturale', 'storia', 'smarrito', 'rafforzante', 'enfatizzare', 'famoso', 'cospirativo', 'alienazione', 'allettante', 'alterativo', 'posta', 'ingiustificato', 'sorpresa', 'fatica', 'veramente', 'suggerito', 'porre', 'continuativo', 'potenzare', 'rabboccare', 'cospiratorio', 'interrogativo', 'fiducia', 'esclusivo', 'validute', 'interpersonale', 'bombardare', 'autismo', 'oculato', 'immaginare', 'metodico', 'sintomo', 'molteplicità', 'perseguire', 'aspetto', 'giovare', 'risonante', 'oppressione', 'accattivante', 'dubbia', 'contrastamento', 'sottaciutte', 'riferire', 'invasivo', 'checkers', 'svegliare', 'fungere', 'sociale', 'esterno', 'established', 'allerta', 'accettare', 'accentuare', 'soddisfare', 'penalizzare', 'congegnare', 'autoalimentare', 'viralmente', 'flaggare', 'ente', 'nazione', 'approvato', 'serio', 'ribelle', 'illuminare', 'controversia', 'capiscano', 'esposizione', 'amplificazione', 'esistano', 'approvazione', 'sminuirle', 'vantaggio', 'spirituale', 'priorizzare', 'rifiutare li', 'concreto', 'degenerare', 'rabbia', 'violenza', 'entità', 'corporato', 'intrecciare', 'estirpare la', 'corrispondere', 'caos', 'scritto', 'insormontabile', 'sviluppiare', 'fraintesi', 'incrinare', 'attrezzatura', 'notevole', 'policy', 'detenere', 'regola', 'razzo', 'indurre', 'explanations', 'professionista', 'leva', 'persuase', 'fame', 'sfumato', 'talidomide', 'luminaro', 'gonfiare', 'promosse', 'increm ...
# {'mediatore', 'etico', 'volontario', 'prestigio', 'sicuro', 'importanza', 'ricchezza', 'guarire', 'coalizione', 'desideroso', 'compreso', 'veloce', 'gentile', 'restaurare', 'eroe', 'prevalere', 'intuitivo', 'canto', 'comprensione', 'assumere', 'prevedere', 'gratificare', 'bambino', 'ordinato', 'regolare', 'antidoto', 'caro', 'resiliente', 'unico', 'morale', 'recupero', 'riuscito', 'fertile', 'autore', 'modificare', 'organizzazione', 'informazione', 'crescere', 'armonia', 'compatibile', 'istruire', 'forte', 'indipendenza', 'cooperativa', 'fermezza', 'fornire', 'volontà', 'paziente', 'precedenza', 'evidente', 'durevole', 'infallibile', 'abilitare', 'interessante', 'legale', 'risalto', 'responsabilità', 'conforto', 'guida', 'ricevuto', 'notevolmente', 'produzione', 'salvaguardia', 'infanzia', 'profondità', 'divertimento', 'veridicità', 'ricercatore', 'colpito', 'invitare', 'correttivo', 'vigilanza', 'completare', 'longevità', 'contribuire', 'placare', 'immergere', 'moderare', 'meritare', 'spirito', 'discorso', 'solidità', 'specie', 'preferire', 'alleviare', 'metropolitano', 'migliorato', 'ostinato', 'rinvigorire', 'stragrande', 'inconfutabile', 'conformità', 'aumentare', 'costruire', 'approvare', 'convincere', 'scoperta', 'compassione', 'popolarità', 'guadagno', 'sollievo', 'completo', 'autorità', 'incluso', 'alimentazione', 'fisico', 'compassionevole', 'libertà', 'consapevolezza', 'esperto', 'racconto', 'magico', 'apprendimento', 'complementare', 'difendere', 'logico', 'speranza', 'educato', 'scegliere', 'contare', 'chiarezza', 'monetario', 'potenziare', 'modello', 'realizzazione', 'credibilità', 'professionale', 'etica', 'compagnia', 'rispettabile', 'robusto', 'ingegno', 'sottolineare', 'dichiarazione', 'guarigione', 'sposare', 'tecnologia', 'moralità', 'adatto', 'entusiasmo', 'umano', 'rivedere', 'nucleo', 'punto', 'sforzo', 'rinascita', 'promozione', 'soluzione', 'resistenza', 'rivendicazione', 'sincerità', 'sorprendentemente', 'rivoluzionario', 'cooperazione', 'merito', 'resistere', 'completamento', 'raggiungere', 'visione', 'diversificato', 'genuino', 'corroborare', 'imparziale', 'cascata', 'familiarità', 'corretto', 'illimitato', 'pubblico', 'prezioso', 'prolifico', 'capacità', 'valore', 'tendenza', 'deliberato', 'garantire', 'creare', 'produrre', 'emozionante', 'gestire', 'vigore', 'memorabile', 'chiarire', 'impegnato', 'uguaglianza', 'potente', 'riconoscimento', 'coinvolgente', 'coltivare', 'efficiente', 'livello', 'competente', 'umanità', 'predominante', 'benedizione', 'nozione', 'rimedio', 'miracolo', 'unito', 'determinazione', 'accordo', 'discussione', 'affidabile', 'disposto', 'potenza', 'spalla', 'presto', 'credito', 'rispettoso', 'governativo', 'prosperare', 'puntuale', 'motore', 'curioso', 'compito', 'avanzare', 'solido', 'sincero', 'tipo', 'sostanziale', 'elevazione', 'popolazione', 'rafforzare', 'fortemente', 'degno', 'faro', 'minore', 'invito', 'vincere', 'fedele', 'cooperare', 'importante', 'empatia', 'collaborazione', 'civiltà', 'contatto', 'miracoloso', 'civile', 'preparare', 'sano', 'eroico', 'assistere', 'cognitivo', 'tentativo', 'educare', 'comunicare', 'promettente', 'influente', 'avanzamento', 'celebre', 'occupare', 'organizzare', 'tempestivo', 'prontezza', 'completamente', 'nutrimento', 'intellettuale', 'raggiungimento', 'aiuto', 'opportunità', 'arte', 'fondare', 'razionale', 'percepire', 'maggioranza', 'moderazione', 'ininterrotto', 'rassicurare', 'società', 'verità', 'forma', 'sostenitore', 'auspicabile', 'integrità', 'avvincente', 'coerente', 'tutela', 'rafforzamento', 'comprensivo', 'ricevere', 'salutare', 'primario', 'domanda', 'determinato', 'lieto', 'partecipare', 'accessibile', 'scherzo', 'imparare', 'semplice', 'consigliare', 'igienico', 'peso', 'nutrire', 'svelare', 'consigliabile', 'coro', 'guardia', 'collettivamente', 'palliativo', 'familiare', 'mare', 'attento', 'assicurare', 'ministero', 'maggiore', 'apprezzamento', 'prevenzione', 'responsabile', 'azione', 'interessato', 'equilibrato', 'p ...
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350

# %% [markdown]
# # Utilities

# %%
def valence_metrics(weighted_network, model, topic, language='english'):
    
    positive, negative, neutral = get_valence_sets(weighted_network, language=language)
    random_positive, random_negative, random_neutral = swap_elements_in_sets(positive, negative, neutral)

    def get_valence(word):
        if word in positive:
            return 'positive'
        elif word in negative:
            return 'negative'
        else:
            return 'neutral'
        
    def get_random_valence(word):
        if word in random_positive:
            return 'positive'
        elif word in random_negative:
            return 'negative'
        else:
            return 'neutral'

    # Weighted network analysis
    weight_pos_pos, weight_pos_neutral, weight_pos_neg,weight_neg_neutral, weight_neg_neg, weight_neutral_neutral = 0, 0, 0, 0, 0, 0
    random_weight_pos_pos, random_weight_pos_neutral, random_weight_pos_neg, random_weight_neg_neutral, random_weight_neg_neg, random_weight_neutral_neutral = 0, 0, 0, 0, 0, 0
    
    for node1, node2, weight in weighted_network:
        valence1, valence2 = get_valence(node1), get_valence(node2)
        random_valence1, random_valence2 = get_random_valence(node1), get_random_valence(node2)
        
        # Normal distribution
        if valence1 == 'positive' and valence2 == 'positive':
            weight_pos_pos += weight
        elif (valence1 == 'positive' and valence2 == 'neutral') or (valence1 == 'neutral' and valence2 == 'positive'):
            weight_pos_neutral += weight
        elif (valence1 == 'negative' and valence2 == 'neutral') or (valence1 == 'neutral' and valence2 == 'negative'):
            weight_neg_neutral += weight
        elif valence1 == 'negative' and valence2 == 'negative':
            weight_neg_neg += weight
        elif valence1 == 'neutral' and valence2 == 'neutral':
            weight_neutral_neutral += weight
        elif (valence1 == 'negative' and valence2 == 'positive') or (valence1 == 'positive' and valence2 == 'negative'):
            weight_pos_neg += weight
        
        # Random distribution
        if random_valence1 == 'positive' and random_valence2 == 'positive':
            random_weight_pos_pos += weight
        elif (random_valence1 == 'positive' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'positive'):
            random_weight_pos_neutral += weight
        elif (random_valence1 == 'negative' and random_valence2 == 'neutral') or (random_valence1 == 'neutral' and random_valence2 == 'negative'):
            random_weight_neg_neutral += weight
        elif random_valence1 == 'negative' and random_valence2 == 'negative':
            random_weight_neg_neg += weight
        elif random_valence1 == 'neutral' and random_valence2 == 'neutral':
            random_weight_neutral_neutral += weight
        elif (random_valence1 == 'negative' and random_valence2 == 'positive') or (random_valence1 == 'positive' and random_valence2 == 'negative'):
            random_weight_pos_neg += weight
    
    print("\nWeighted Network Metrics:")
    print(f"Total weight of edges between positive nodes: {weight_pos_pos}")
    print(f"Total weight of edges between positive and neutral nodes: {weight_pos_neutral}")
    print(f"Total weight of edges between negative and neutral nodes: {weight_neg_neutral}")
    print(f"Total weight of edges between negative nodes: {weight_neg_neg}")
    print(f"Total weight of edges between neutral nodes: {weight_neutral_neutral}")
    print(f"Total weight of edges between contrasting nodes: {weight_pos_neg}")
    
    print("\nRandom Distribution Metrics:")
    print(f"Total weight of edges between positive nodes: {random_weight_pos_pos}")
    print(f"Total weight of edges between positive and neutral nodes: {random_weight_pos_neutral}")
    print(f"Total weight of edges between negative and neutral nodes: {random_weight_neg_neutral}")
    print(f"Total weight of edges between negative nodes: {random_weight_neg_neg}")
    print(f"Total weight of edges between neutral nodes: {random_weight_neutral_neutral}")
    print(f"Total weight of edges between contrasting nodes: {random_weight_pos_neg}")
    
    # Calculate z-scores
    normal_weights = [weight_pos_pos, weight_pos_neutral, weight_neg_neutral, weight_neg_neg, weight_neutral_neutral,weight_pos_neg]
    random_weights = [random_weight_pos_pos, random_weight_pos_neutral, random_weight_neg_neutral, random_weight_neg_neg, random_weight_neutral_neutral,random_weight_pos_neg]
    
    z_scores = stats.zscore(normal_weights + random_weights)[:len(normal_weights)]
    
    print("\nZ-scores (Normal vs Random):")
    for label, z_score in zip(['Positive-Positive', 'Positive-Neutral', 'Negative-Neutral', 'Negative-Negative', 'Neutral-Neutral','Positive-Negative'], z_scores):
        print(f"{label}: {z_score:.2f}")
    
    # Plotting
    labels = ['Positive-Positive', 'Positive-Neutral', 'Negative-Neutral', 'Negative-Negative', 'Neutral-Neutral','Positive-Negative']
    normal_sizes = normal_weights
    random_sizes = random_weights
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
    
    ax1.pie(normal_sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    ax1.set_title('Normal Valence Distribution')
    
    ax2.pie(random_sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    ax2.set_title('Random Valence Distribution')
    
    plt.suptitle(f'Distribution of Edge Weights by Node Valence for model {model} and topic {topic}: Normal vs Random')
    plt.show()
# Example usage:

#valence_metrics(w_fmnt,'Haiku','climate')

# %%
for folder in folders_of_interest:
    folder_path = os.path.join(base_output_dir, folder)

    for filename in os.listdir(folder_path):
        #print(filename.rstrip('.jsonl'))

        if '(ITA)' in filename:
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                
                fmnts=[]

                for line in file:
                    data = json.loads(line)
                    fmnts.append(data['fmnt']['syntactic'])
                weighted_fmnt = emos.combine_edgelists(fmnts)
                print(len(weighted_fmnt))
                print(weighted_fmnt[0])
                valence_metrics(weighted_fmnt,filename.rstrip('.jsonl'),folder,language='italian')
